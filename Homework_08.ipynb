# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: July 5th @ 11:59pm (with usual 2 hour + 1 minute grace period)
#
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 11 graded problems, each worth 5 points.

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.18.5-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.51)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 9.4 MB/s eta 0:00:00
# Downloading alembic-1.18.5-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 24.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.18.5 colorlog-6.10.1 optuna-4.9.0

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display

# Data source
from sklearn.datasets import fetch_openml


# scikit-learn core tools
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder


# Import model
from sklearn.ensemble import HistGradientBoostingClassifier

# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report

# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 0: Installing Optuna (if needed)
#
# Optuna is not included in every Python installation. If the statement
#
# ```python
# import optuna
# ```
#
# produces
#
# ```
# ModuleNotFoundError: No module named 'optuna'
# ```
#
# then install it using one of the following methods.
#
# **If you are using Anaconda (recommended):**
#
# ```bash
# conda install -c conda-forge optuna
# ```
#
# **Or using pip:**
#
# ```bash
# pip install optuna
# ```
#
# If you are working in a Jupyter notebook, you can also install it directly from a code cell:
#
# ```python
# %pip install optuna
# ```
#
# or
#
# ```python
# !pip install optuna
# ```
#
# After the installation finishes, **restart the Jupyter kernel** and rerun the notebook from the beginning.

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3
    max_depth=None,
    min_samples_leaf=20,
    l2_regularization=0.0,

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
# Your code here

# 5 fold Cross Validation:
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)

# cross_val_score to estimate the mean F1 score
f1_score = cross_val_score(pipelined_model, X_train, y_train, cv=cv, scoring="f1", n_jobs=-1)

# The mean and standard deviation of the F1 score
print(f"Mean F1 Score: {np.mean(f1_score):.4f}")
print(f"Standard Deviation: {np.std(f1_score):.4f}")
# Out:
# Mean F1 Score: 0.7123
# Standard Deviation: 0.0035

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = np.mean(f1_score)                    # replace 0 with an expression

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7123

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
# Your code here

# 5 fold Cross Validation:
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)

#Hyperparameter
param_dist = {"gb__learning_rate": loguniform(1e-3, 0.3),
              "gb__max_leaf_nodes": randint(16, 257),
              "gb__max_depth": randint(2,11),
              "gb__min_samples_leaf": randint(10, 201),
              "gb__l2_regularization": uniform(0.0, 2.0)}

#Rndomized Search
random_search =  RandomizedSearchCV(estimator=pipelined_model,
                                    param_distributions=param_dist,
                                    n_iter=80,
                                    scoring="f1",
                                    cv=cv,
                                    random_state=random_seed,
                                    n_jobs=-1,
                                    return_train_score=False,
                                    verbose=1)

#fit the model
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(transformers=[('cat',
#                                                                                OrdinalEncoder(dtype=<class 'numpy.int64'>,
#                                                                                               encoded_missing_value=-2,
#                                                                                               handle_unknown='use_encoded_value',
#                                                                                               unknown_value=-1),
#                                                                                ['workclass',
#                                                                                 'marital-status',
#                                                                                 'occupation',
#                                                                                 'relationship',
#                                                                                 'race',
#                                                                                 'sex',
#                                                                                 'native...
#                                         'gb__learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7dfd9b901a00>,
#                                         'gb__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7dfd9849bc80>,
#                                         'gb__max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7dfd9b9079e0>,
#                                         'gb__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7dfd9849b8f0>},
#                    random_state=42, scoring='f1', verbose=1)

# %%
#Top 5 results:
results = pd.DataFrame(random_search.cv_results_)

top_5 = (results[["mean_test_score",
                  "std_test_score",
                  "param_gb__learning_rate",
                  "param_gb__max_leaf_nodes",
                  "param_gb__max_depth",
                  "param_gb__min_samples_leaf",
                  "param_gb__l2_regularization"]].sort_values("mean_test_score", ascending=False)
                  .head(5).rename(columns={"mean_test_score": "Mean F1",
                  "std_test_score": "Std F1",
                  "param_gb__learning_rate": "Learning Rate",
                  "param_gb__max_leaf_nodes": "Max Leaf Nodes",
                  "param_gb__max_depth": "Max Depth",
                  "param_gb__min_samples_leaf": "Min Samples Leaf",
                  "param_gb__l2_regularization": "L2 Regularization"}))
display(top_5)
print("\nBest F1 Score:", random_search.best_score_)
print("\nBest Parameters:", random_search.best_params_)
# Out:
#      Mean F1    Std F1  Learning Rate  Max Leaf Nodes  Max Depth  \
# 19  0.712000  0.003063       0.127541              48          3
# 60  0.711962  0.004237       0.268164             206          5
# 21  0.711405  0.003213       0.157664             242          2
# 59  0.711045  0.003477       0.229549              61          2
# 14  0.711026  0.002790       0.070991              39          6
#
#     Min Samples Leaf  L2 Regularization
# 19                57           1.829919
# 60               169           1.144585
# 21               110           1.275115
# 59               190           1.495438
# 14               163           1.689068
# Best F1 Score: 0.7119997861837095
#
# Best Parameters:
# {'gb__l2_regularization': np.float64(1.8299193510875615), 'gb__learning_rate': np.float64(0.12754065069696732), 'gb__max_depth': 3, 'gb__max_leaf_nodes': 48, 'gb__min_samples_leaf': 57}

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = random_search.best_score_                    # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7120

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Your code here

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_seed
)

def objective(trial):

    params = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 16, 256),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 200),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 2.0),
    }

    model = HistGradientBoostingClassifier(
        **params,
        max_iter=500,
        early_stopping=True,
        n_iter_no_change=20,
        validation_fraction=0.2,
        class_weight="balanced",
        random_state=random_seed
    )

    pipe = Pipeline([
        ("prep", preprocess),
        ("gb", model)
    ])

    scores = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="f1",
        n_jobs=-1
    )

    return scores.mean()

#Optuna study
study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=100)

#top 5 results
results = []

for t in study.trials:
    if t.value is None:
        continue
    results.append({
        "F1 Score": t.value,
        **t.params
    })

df_results = pd.DataFrame(results)

top5 = df_results.sort_values("F1 Score", ascending=False).head(5)

display(top5)
# Out:
# [I 2026-07-05 03:02:03,711] A new study created in memory with name: no-name-f7a9b73b-a7d6-4691-8185-7ff08955a18e
# [I 2026-07-05 03:02:22,636] Trial 0 finished with value: 0.665777379220848 and parameters: {'learning_rate': 0.0024344801378746008, 'max_leaf_nodes': 80, 'max_depth': 6, 'min_samples_leaf': 195, 'l2_regularization': 0.6969088036612561}. Best is trial 0 with value: 0.665777379220848.
# [I 2026-07-05 03:02:36,001] Trial 1 finished with value: 0.7078643946874127 and parameters: {'learning_rate': 0.03522072816370579, 'max_leaf_nodes': 172, 'max_depth': 6, 'min_samples_leaf': 176, 'l2_regularization': 0.1946249369096109}. Best is trial 1 with value: 0.7078643946874127.
# [I 2026-07-05 03:02:43,033] Trial 2 finished with value: 0.7098163174667931 and parameters: {'learning_rate': 0.08687512664666111, 'max_leaf_nodes': 58, 'max_depth': 10, 'min_samples_leaf': 118, 'l2_regularization': 1.6136586829945287}. Best is trial 2 with value: 0.7098163174667931.
# [I 2026-07-05 03:03:06,301] Trial 3 finished with value: 0.7046577915311345 and parameters: {'learning_rate': 0.014675365292010165, 'max_leaf_nodes': 99, 'max_depth': 10, 'min_samples_leaf': 76, 'l2_regularization': 1.1875945061136353}. Best is trial 2 with value: 0.7098163174667931.
# [I 2026-07-05 03:03:18,946] Trial 4 finished with value: 0.7025784923704937 and parameters: {'learning_rate': 0.02708026683427524, 'max_leaf_nodes': 213, 'max_depth': 4, 'min_samples_leaf': 141, 'l2_regularization': 0.1011238913581185}. Best is trial 2 with value: 0.7098163174667931.
# [I 2026-07-05 03:03:23,999] Trial 5 finished with value: 0.709600163393828 and parameters: {'learning_rate': 0.16661809987156329, 'max_leaf_nodes': 118, 'max_depth': 10, 'min_samples_leaf': 125, 'l2_regularization': 0.18352207815815325}. Best is trial 2 with value: 0.7098163174667931.
# [I 2026-07-05 03:03:31,838] Trial 6 finished with value: 0.7113090235991795 and parameters: {'learning_rate': 0.10835101218292573, 'max_leaf_nodes': 212, 'max_depth': 2, 'min_samples_leaf': 33, 'l2_regularization': 0.7452724046358756}. Best is trial 6 with value: 0.7113090235991795.
# [I 2026-07-05 03:03:55,230] Trial 7 finished with value: 0.7011839541907963 and parameters: {'learning_rate': 0.010192305049032417, 'max_leaf_nodes': 123, 'max_depth': 10, 'min_samples_leaf': 101, 'l2_regularization': 1.6396424766027697}. Best is trial 6 with value: 0.7113090235991795.
# [I 2026-07-05 03:04:08,131] Trial 8 finished with value: 0.7064723250525348 and parameters: {'learning_rate': 0.027481189970153433, 'max_leaf_nodes': 72, 'max_depth': 5, 'min_samples_leaf': 94, 'l2_regularization': 0.5773779842512308}. Best is trial 6 with value: 0.7113090235991795.
# [I 2026-07-05 03:04:36,122] Trial 9 finished with value: 0.6911808603216836 and parameters: {'learning_rate': 0.006366147556674669, 'max_leaf_nodes': 155, 'max_depth': 10, 'min_samples_leaf': 76, 'l2_regularization': 0.5395092802879855}. Best is trial 6 with value: 0.7113090235991795.
# [I 2026-07-05 03:04:40,451] Trial 10 finished with value: 0.7112803635688023 and parameters: {'learning_rate': 0.29918400020695374, 'max_leaf_nodes': 256, 'max_depth': 2, 'min_samples_leaf': 18, 'l2_regularization': 1.1303350212320211}. Best is trial 6 with value: 0.7113090235991795.
# [I 2026-07-05 03:04:47,575] Trial 11 finished with value: 0.7128070757059308 and parameters: {'learning_rate': 0.29418415628207034, 'max_leaf_nodes': 254, 'max_depth': 2, 'min_samples_leaf': 11, 'l2_regularization': 1.0600152837091104}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:04:55,113] Trial 12 finished with value: 0.7122932544254004 and parameters: {'learning_rate': 0.11014793800302805, 'max_leaf_nodes': 253, 'max_depth': 2, 'min_samples_leaf': 12, 'l2_regularization': 1.0591843376837822}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:00,565] Trial 13 finished with value: 0.7107868051463416 and parameters: {'learning_rate': 0.2800583639787873, 'max_leaf_nodes': 256, 'max_depth': 3, 'min_samples_leaf': 43, 'l2_regularization': 1.1438458079715614}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:09,303] Trial 14 finished with value: 0.7116735131805987 and parameters: {'learning_rate': 0.06605562947071152, 'max_leaf_nodes': 17, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 1.3743697186824775}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:17,502] Trial 15 finished with value: 0.7127255624218762 and parameters: {'learning_rate': 0.16222120013882838, 'max_leaf_nodes': 221, 'max_depth': 2, 'min_samples_leaf': 52, 'l2_regularization': 1.942906538847196}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:21,683] Trial 16 finished with value: 0.7097919584439256 and parameters: {'learning_rate': 0.18867257050185182, 'max_leaf_nodes': 212, 'max_depth': 4, 'min_samples_leaf': 54, 'l2_regularization': 1.973273612171}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:33,015] Trial 17 finished with value: 0.7103728427001148 and parameters: {'learning_rate': 0.052861542430853045, 'max_leaf_nodes': 179, 'max_depth': 8, 'min_samples_leaf': 67, 'l2_regularization': 1.9834673419301172}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:41,140] Trial 18 finished with value: 0.7117688137057445 and parameters: {'learning_rate': 0.14278598016202548, 'max_leaf_nodes': 221, 'max_depth': 3, 'min_samples_leaf': 36, 'l2_regularization': 1.6552082831304622}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:53,104] Trial 19 finished with value: 0.6395986886838726 and parameters: {'learning_rate': 0.0012262562468848914, 'max_leaf_nodes': 231, 'max_depth': 4, 'min_samples_leaf': 55, 'l2_regularization': 1.4350411727734047}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:05:59,518] Trial 20 finished with value: 0.7113905969850605 and parameters: {'learning_rate': 0.22140782150200478, 'max_leaf_nodes': 185, 'max_depth': 2, 'min_samples_leaf': 29, 'l2_regularization': 0.9591508930271352}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:08,518] Trial 21 finished with value: 0.712311289328289 and parameters: {'learning_rate': 0.1069856456155246, 'max_leaf_nodes': 237, 'max_depth': 2, 'min_samples_leaf': 11, 'l2_regularization': 0.8831980742849816}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:17,587] Trial 22 finished with value: 0.70740835637199 and parameters: {'learning_rate': 0.05048936802361304, 'max_leaf_nodes': 235, 'max_depth': 3, 'min_samples_leaf': 50, 'l2_regularization': 0.8808071730526493}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:25,368] Trial 23 finished with value: 0.7121559518699583 and parameters: {'learning_rate': 0.14114597283726, 'max_leaf_nodes': 198, 'max_depth': 2, 'min_samples_leaf': 25, 'l2_regularization': 0.345878518795261}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:35,515] Trial 24 finished with value: 0.7104052210986842 and parameters: {'learning_rate': 0.06272642649029665, 'max_leaf_nodes': 155, 'max_depth': 3, 'min_samples_leaf': 25, 'l2_regularization': 1.8224777705489148}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:43,083] Trial 25 finished with value: 0.7102311169809595 and parameters: {'learning_rate': 0.09313685476226204, 'max_leaf_nodes': 234, 'max_depth': 4, 'min_samples_leaf': 66, 'l2_regularization': 1.4083937423045816}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:51,404] Trial 26 finished with value: 0.7121639970823891 and parameters: {'learning_rate': 0.20061048581276705, 'max_leaf_nodes': 197, 'max_depth': 2, 'min_samples_leaf': 42, 'l2_regularization': 0.39116290641747753}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:06:54,622] Trial 27 finished with value: 0.7084022338276884 and parameters: {'learning_rate': 0.296266616294949, 'max_leaf_nodes': 239, 'max_depth': 5, 'min_samples_leaf': 88, 'l2_regularization': 0.8262941963164288}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:07:02,425] Trial 28 finished with value: 0.71277317906399 and parameters: {'learning_rate': 0.12441543120607966, 'max_leaf_nodes': 195, 'max_depth': 3, 'min_samples_leaf': 11, 'l2_regularization': 1.2461616851158706}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:07:14,236] Trial 29 finished with value: 0.7078208805743367 and parameters: {'learning_rate': 0.03639131318349781, 'max_leaf_nodes': 159, 'max_depth': 5, 'min_samples_leaf': 176, 'l2_regularization': 1.2877006735521324}. Best is trial 11 with value: 0.7128070757059308.
# [I 2026-07-05 03:07:21,135] Trial 30 finished with value: 0.7130073306857141 and parameters: {'learning_rate': 0.1579513433328707, 'max_leaf_nodes': 195, 'max_depth': 3, 'min_samples_leaf': 62, 'l2_regularization': 1.8077256622061126}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:07:32,568] Trial 31 finished with value: 0.7116149168260213 and parameters: {'learning_rate': 0.160010281345948, 'max_leaf_nodes': 194, 'max_depth': 3, 'min_samples_leaf': 67, 'l2_regularization': 1.8319440998673637}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:07:44,456] Trial 32 finished with value: 0.7105572141137954 and parameters: {'learning_rate': 0.07806044174492151, 'max_leaf_nodes': 167, 'max_depth': 3, 'min_samples_leaf': 47, 'l2_regularization': 1.7770920848072977}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:07:48,565] Trial 33 finished with value: 0.7106496328419969 and parameters: {'learning_rate': 0.22665147010624548, 'max_leaf_nodes': 220, 'max_depth': 4, 'min_samples_leaf': 22, 'l2_regularization': 1.5250403948810165}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:01,163] Trial 34 finished with value: 0.7105378629548029 and parameters: {'learning_rate': 0.11797095227192214, 'max_leaf_nodes': 145, 'max_depth': 6, 'min_samples_leaf': 82, 'l2_regularization': 1.7422526014438184}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:15,600] Trial 35 finished with value: 0.7054349886770892 and parameters: {'learning_rate': 0.04316688663132511, 'max_leaf_nodes': 204, 'max_depth': 3, 'min_samples_leaf': 102, 'l2_regularization': 1.5424405660548923}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:25,137] Trial 36 finished with value: 0.710318813937602 and parameters: {'learning_rate': 0.1621757479573046, 'max_leaf_nodes': 179, 'max_depth': 2, 'min_samples_leaf': 200, 'l2_regularization': 1.2717450046199263}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:36,784] Trial 37 finished with value: 0.7099807663256692 and parameters: {'learning_rate': 0.07052489658358567, 'max_leaf_nodes': 136, 'max_depth': 8, 'min_samples_leaf': 58, 'l2_regularization': 1.9100117243706252}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:45,362] Trial 38 finished with value: 0.7097586147030747 and parameters: {'learning_rate': 0.206135514045486, 'max_leaf_nodes': 188, 'max_depth': 4, 'min_samples_leaf': 116, 'l2_regularization': 0.9949832689555483}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:08:55,111] Trial 39 finished with value: 0.6875268550664526 and parameters: {'learning_rate': 0.023596551043760107, 'max_leaf_nodes': 223, 'max_depth': 2, 'min_samples_leaf': 33, 'l2_regularization': 1.7094641581037378}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:10,137] Trial 40 finished with value: 0.6663440130983045 and parameters: {'learning_rate': 0.003378008394471451, 'max_leaf_nodes': 246, 'max_depth': 5, 'min_samples_leaf': 142, 'l2_regularization': 1.5479697562124992}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:21,894] Trial 41 finished with value: 0.7096896265176851 and parameters: {'learning_rate': 0.09210182360257481, 'max_leaf_nodes': 209, 'max_depth': 2, 'min_samples_leaf': 11, 'l2_regularization': 0.656652824747062}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:30,883] Trial 42 finished with value: 0.7125496669055895 and parameters: {'learning_rate': 0.11589968117226578, 'max_leaf_nodes': 226, 'max_depth': 3, 'min_samples_leaf': 18, 'l2_regularization': 0.779876030165209}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:40,840] Trial 43 finished with value: 0.7124836799409582 and parameters: {'learning_rate': 0.1295506413459301, 'max_leaf_nodes': 228, 'max_depth': 3, 'min_samples_leaf': 39, 'l2_regularization': 0.7588462419655009}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:45,470] Trial 44 finished with value: 0.7119593389112755 and parameters: {'learning_rate': 0.2592678099685185, 'max_leaf_nodes': 214, 'max_depth': 4, 'min_samples_leaf': 20, 'l2_regularization': 1.237432525427007}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:09:52,210] Trial 45 finished with value: 0.7110808027020589 and parameters: {'learning_rate': 0.16620019815345013, 'max_leaf_nodes': 245, 'max_depth': 3, 'min_samples_leaf': 33, 'l2_regularization': 1.0549164675756644}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:10:03,352] Trial 46 finished with value: 0.7085009892439941 and parameters: {'learning_rate': 0.08699910544068948, 'max_leaf_nodes': 170, 'max_depth': 2, 'min_samples_leaf': 62, 'l2_regularization': 0.5279717082595633}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:10:16,624] Trial 47 finished with value: 0.7110555312479769 and parameters: {'learning_rate': 0.12360461979280683, 'max_leaf_nodes': 201, 'max_depth': 3, 'min_samples_leaf': 77, 'l2_regularization': 0.008119250059707817}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:10:46,426] Trial 48 finished with value: 0.7101475327028195 and parameters: {'learning_rate': 0.018590454915689066, 'max_leaf_nodes': 218, 'max_depth': 7, 'min_samples_leaf': 18, 'l2_regularization': 1.8950547263853257}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:10:52,622] Trial 49 finished with value: 0.7117169172505161 and parameters: {'learning_rate': 0.23908937067296246, 'max_leaf_nodes': 35, 'max_depth': 4, 'min_samples_leaf': 48, 'l2_regularization': 0.6754214810745702}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:02,935] Trial 50 finished with value: 0.7117208645088263 and parameters: {'learning_rate': 0.18364814026664028, 'max_leaf_nodes': 251, 'max_depth': 2, 'min_samples_leaf': 29, 'l2_regularization': 1.08852589886869}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:12,684] Trial 51 finished with value: 0.712021398007976 and parameters: {'learning_rate': 0.13280761735854363, 'max_leaf_nodes': 226, 'max_depth': 3, 'min_samples_leaf': 39, 'l2_regularization': 0.7289206790067717}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:25,772] Trial 52 finished with value: 0.7115212168609009 and parameters: {'learning_rate': 0.09653424767836902, 'max_leaf_nodes': 227, 'max_depth': 3, 'min_samples_leaf': 41, 'l2_regularization': 0.4339044888944713}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:35,208] Trial 53 finished with value: 0.7127707192584506 and parameters: {'learning_rate': 0.13417192831823116, 'max_leaf_nodes': 98, 'max_depth': 3, 'min_samples_leaf': 19, 'l2_regularization': 0.7986925434811994}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:48,141] Trial 54 finished with value: 0.7054932296178281 and parameters: {'learning_rate': 0.05761124502706444, 'max_leaf_nodes': 94, 'max_depth': 2, 'min_samples_leaf': 17, 'l2_regularization': 0.9048216117061723}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:11:52,293] Trial 55 finished with value: 0.7096748639667739 and parameters: {'learning_rate': 0.1769632866066134, 'max_leaf_nodes': 55, 'max_depth': 4, 'min_samples_leaf': 27, 'l2_regularization': 1.197533672415589}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:02,530] Trial 56 finished with value: 0.7123840774080975 and parameters: {'learning_rate': 0.07404959678283454, 'max_leaf_nodes': 107, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 0.8135903735222034}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:08,551] Trial 57 finished with value: 0.7119473458710561 and parameters: {'learning_rate': 0.239770695499718, 'max_leaf_nodes': 121, 'max_depth': 2, 'min_samples_leaf': 19, 'l2_regularization': 0.9752913542905032}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:18,264] Trial 58 finished with value: 0.7104087999463881 and parameters: {'learning_rate': 0.1111842934810065, 'max_leaf_nodes': 77, 'max_depth': 2, 'min_samples_leaf': 53, 'l2_regularization': 1.3463781209909569}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:24,081] Trial 59 finished with value: 0.7122958541755858 and parameters: {'learning_rate': 0.1488833607609601, 'max_leaf_nodes': 207, 'max_depth': 3, 'min_samples_leaf': 32, 'l2_regularization': 0.6051890996643585}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:28,026] Trial 60 finished with value: 0.7110781818985283 and parameters: {'learning_rate': 0.2974345244892791, 'max_leaf_nodes': 241, 'max_depth': 4, 'min_samples_leaf': 15, 'l2_regularization': 1.640050364548197}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:34,848] Trial 61 finished with value: 0.7112081474454552 and parameters: {'learning_rate': 0.12848943902354984, 'max_leaf_nodes': 256, 'max_depth': 3, 'min_samples_leaf': 39, 'l2_regularization': 0.8204233343316063}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:41,147] Trial 62 finished with value: 0.7120283397293533 and parameters: {'learning_rate': 0.1903916498649648, 'max_leaf_nodes': 231, 'max_depth': 3, 'min_samples_leaf': 24, 'l2_regularization': 0.7571443946841026}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:48,683] Trial 63 finished with value: 0.7104778398107496 and parameters: {'learning_rate': 0.11122163229080007, 'max_leaf_nodes': 190, 'max_depth': 2, 'min_samples_leaf': 44, 'l2_regularization': 0.4625616438383674}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:12:56,677] Trial 64 finished with value: 0.7107984831852356 and parameters: {'learning_rate': 0.14004519848369568, 'max_leaf_nodes': 65, 'max_depth': 3, 'min_samples_leaf': 36, 'l2_regularization': 1.988335079611914}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:05,801] Trial 65 finished with value: 0.7105378353214846 and parameters: {'learning_rate': 0.08246208008406174, 'max_leaf_nodes': 179, 'max_depth': 3, 'min_samples_leaf': 71, 'l2_regularization': 0.6074252472612662}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:16,882] Trial 66 finished with value: 0.6680469297000673 and parameters: {'learning_rate': 0.008965951692164536, 'max_leaf_nodes': 247, 'max_depth': 2, 'min_samples_leaf': 61, 'l2_regularization': 0.2710690532034059}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:27,664] Trial 67 finished with value: 0.7100637494588254 and parameters: {'learning_rate': 0.04827241073925357, 'max_leaf_nodes': 133, 'max_depth': 5, 'min_samples_leaf': 25, 'l2_regularization': 0.9285549623439715}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:37,031] Trial 68 finished with value: 0.7106706965334728 and parameters: {'learning_rate': 0.10062231307565567, 'max_leaf_nodes': 237, 'max_depth': 3, 'min_samples_leaf': 49, 'l2_regularization': 1.157871907495695}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:40,413] Trial 69 finished with value: 0.7110957512160945 and parameters: {'learning_rate': 0.21464163770387756, 'max_leaf_nodes': 215, 'max_depth': 4, 'min_samples_leaf': 16, 'l2_regularization': 1.055694059077934}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:49,376] Trial 70 finished with value: 0.7055886727112273 and parameters: {'learning_rate': 0.06466855524219182, 'max_leaf_nodes': 93, 'max_depth': 2, 'min_samples_leaf': 30, 'l2_regularization': 0.7786857865863814}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:13:58,077] Trial 71 finished with value: 0.7121068978788513 and parameters: {'learning_rate': 0.06887324532755458, 'max_leaf_nodes': 106, 'max_depth': 3, 'min_samples_leaf': 13, 'l2_regularization': 0.8390547906277801}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:08,530] Trial 72 finished with value: 0.712630091494693 and parameters: {'learning_rate': 0.07694413386163906, 'max_leaf_nodes': 49, 'max_depth': 3, 'min_samples_leaf': 11, 'l2_regularization': 0.7176665811293846}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:14,398] Trial 73 finished with value: 0.7114984431781262 and parameters: {'learning_rate': 0.15475290873448047, 'max_leaf_nodes': 43, 'max_depth': 4, 'min_samples_leaf': 24, 'l2_regularization': 0.7099062898722628}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:24,346] Trial 74 finished with value: 0.7114334826533366 and parameters: {'learning_rate': 0.038556503940632335, 'max_leaf_nodes': 32, 'max_depth': 9, 'min_samples_leaf': 10, 'l2_regularization': 0.5362998449689289}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:30,858] Trial 75 finished with value: 0.7127184190341657 and parameters: {'learning_rate': 0.26206018021544986, 'max_leaf_nodes': 230, 'max_depth': 3, 'min_samples_leaf': 21, 'l2_regularization': 1.8711324822876252}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:40,539] Trial 76 finished with value: 0.7118746108389076 and parameters: {'learning_rate': 0.23921878951745038, 'max_leaf_nodes': 162, 'max_depth': 2, 'min_samples_leaf': 21, 'l2_regularization': 1.89010021869357}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:49,241] Trial 77 finished with value: 0.7117653754113956 and parameters: {'learning_rate': 0.265487656176258, 'max_leaf_nodes': 16, 'max_depth': 3, 'min_samples_leaf': 18, 'l2_regularization': 1.713605499230929}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:14:59,818] Trial 78 finished with value: 0.7124540443798818 and parameters: {'learning_rate': 0.1991533436478585, 'max_leaf_nodes': 145, 'max_depth': 4, 'min_samples_leaf': 167, 'l2_regularization': 1.8326027753493952}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:15:13,919] Trial 79 finished with value: 0.7125166384563493 and parameters: {'learning_rate': 0.17509990797692998, 'max_leaf_nodes': 242, 'max_depth': 2, 'min_samples_leaf': 29, 'l2_regularization': 1.9309509609934505}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:15:29,152] Trial 80 finished with value: 0.7119677507833992 and parameters: {'learning_rate': 0.08471402256777504, 'max_leaf_nodes': 203, 'max_depth': 3, 'min_samples_leaf': 15, 'l2_regularization': 1.7866168582777786}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:15:41,937] Trial 81 finished with value: 0.7128886171064502 and parameters: {'learning_rate': 0.178120916569853, 'max_leaf_nodes': 242, 'max_depth': 2, 'min_samples_leaf': 28, 'l2_regularization': 1.8996564713146389}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:15:54,703] Trial 82 finished with value: 0.7121222268583335 and parameters: {'learning_rate': 0.15024691881964172, 'max_leaf_nodes': 250, 'max_depth': 2, 'min_samples_leaf': 34, 'l2_regularization': 1.9622957339791427}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:16:05,443] Trial 83 finished with value: 0.7125006238957458 and parameters: {'learning_rate': 0.21434956029187838, 'max_leaf_nodes': 233, 'max_depth': 2, 'min_samples_leaf': 22, 'l2_regularization': 1.4591722402634268}. Best is trial 30 with value: 0.7130073306857141.
# [I 2026-07-05 03:16:20,972] Trial 84 finished with value: 0.7130557709206298 and parameters: {'learning_rate': 0.11472314386979046, 'max_leaf_nodes': 214, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 1.8550282299878686}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:16:24,774] Trial 85 finished with value: 0.7109720326142526 and parameters: {'learning_rate': 0.2646660786612205, 'max_leaf_nodes': 194, 'max_depth': 3, 'min_samples_leaf': 12, 'l2_regularization': 1.859272577522625}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:16:33,805] Trial 86 finished with value: 0.7113615475487587 and parameters: {'learning_rate': 0.10279279479528715, 'max_leaf_nodes': 219, 'max_depth': 2, 'min_samples_leaf': 26, 'l2_regularization': 1.6907899419970767}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:16:39,644] Trial 87 finished with value: 0.7113394118566764 and parameters: {'learning_rate': 0.17158748753927558, 'max_leaf_nodes': 212, 'max_depth': 3, 'min_samples_leaf': 88, 'l2_regularization': 1.5750125402686188}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:16:48,290] Trial 88 finished with value: 0.7107154218274648 and parameters: {'learning_rate': 0.12482173496181836, 'max_leaf_nodes': 23, 'max_depth': 2, 'min_samples_leaf': 44, 'l2_regularization': 1.8011483606610335}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:16:52,799] Trial 89 finished with value: 0.7117236390324896 and parameters: {'learning_rate': 0.14110455840690714, 'max_leaf_nodes': 51, 'max_depth': 4, 'min_samples_leaf': 15, 'l2_regularization': 1.9265255957995646}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:03,394] Trial 90 finished with value: 0.6086208549635251 and parameters: {'learning_rate': 0.0010894725614386963, 'max_leaf_nodes': 180, 'max_depth': 3, 'min_samples_leaf': 56, 'l2_regularization': 1.7417813985638375}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:12,555] Trial 91 finished with value: 0.7128986803331592 and parameters: {'learning_rate': 0.0946824419602461, 'max_leaf_nodes': 221, 'max_depth': 3, 'min_samples_leaf': 21, 'l2_regularization': 1.8597379218416579}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:21,036] Trial 92 finished with value: 0.7112660905915072 and parameters: {'learning_rate': 0.07614055038941113, 'max_leaf_nodes': 222, 'max_depth': 3, 'min_samples_leaf': 20, 'l2_regularization': 1.878219958121762}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:30,656] Trial 93 finished with value: 0.7053417757108105 and parameters: {'learning_rate': 0.059249324096146846, 'max_leaf_nodes': 210, 'max_depth': 2, 'min_samples_leaf': 10, 'l2_regularization': 1.995736133416083}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:47,068] Trial 94 finished with value: 0.7114521329759949 and parameters: {'learning_rate': 0.09152327469392776, 'max_leaf_nodes': 235, 'max_depth': 3, 'min_samples_leaf': 28, 'l2_regularization': 1.7593653315721678}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:17:57,657] Trial 95 finished with value: 0.7122896694509161 and parameters: {'learning_rate': 0.1918159617145165, 'max_leaf_nodes': 242, 'max_depth': 3, 'min_samples_leaf': 35, 'l2_regularization': 1.841649509584887}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:18:06,209] Trial 96 finished with value: 0.7096764614094571 and parameters: {'learning_rate': 0.10755407436960775, 'max_leaf_nodes': 229, 'max_depth': 2, 'min_samples_leaf': 72, 'l2_regularization': 1.956521640608095}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:18:08,856] Trial 97 finished with value: 0.7123409996540836 and parameters: {'learning_rate': 0.2989447342363967, 'max_leaf_nodes': 86, 'max_depth': 4, 'min_samples_leaf': 14, 'l2_regularization': 1.5852368434149884}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:18:19,134] Trial 98 finished with value: 0.6580076932215959 and parameters: {'learning_rate': 0.0038126782149456866, 'max_leaf_nodes': 207, 'max_depth': 3, 'min_samples_leaf': 22, 'l2_regularization': 1.6737122196040661}. Best is trial 84 with value: 0.7130557709206298.
# [I 2026-07-05 03:18:25,950] Trial 99 finished with value: 0.7126511638015742 and parameters: {'learning_rate': 0.16056130497789867, 'max_leaf_nodes': 217, 'max_depth': 2, 'min_samples_leaf': 37, 'l2_regularization': 1.9362333429253002}. Best is trial 84 with value: 0.7130557709206298.
#     F1 Score  learning_rate  max_leaf_nodes  max_depth  min_samples_leaf  \
# 84  0.713056       0.114723             214          3                10
# 30  0.713007       0.157951             195          3                62
# 91  0.712899       0.094682             221          3                21
# 81  0.712889       0.178121             242          2                28
# 11  0.712807       0.294184             254          2                11
#
#     l2_regularization
# 84           1.855028
# 30           1.807726
# 91           1.859738
# 81           1.899656
# 11           1.060015

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = study.best_value                   # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7131

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
best_params = study.best_params #Optuna
print(best_params)
# Out:
# {'learning_rate': 0.11472314386979046, 'max_leaf_nodes': 214, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 1.8550282299878686}

# %%
# Your code here
best_params = study.best_params #Optuna

final_model = HistGradientBoostingClassifier(
    learning_rate=best_params["learning_rate"],
    max_leaf_nodes=best_params["max_leaf_nodes"],
    max_depth=best_params["max_depth"],
    min_samples_leaf=best_params["min_samples_leaf"],
    l2_regularization=best_params["l2_regularization"],

    max_iter=500,
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,

    class_weight="balanced",
    random_state=random_seed
)

final_pipe = Pipeline([
    ("prep", preprocess),
    ("gb", final_model)
])

final_pipe.fit(X_train, y_train)
y_pred = final_pipe.predict(X_test)
print(classification_report(y_test, y_pred))
bal_acc = balanced_accuracy_score(y_test, y_pred)
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      7431
#            1       0.61      0.87      0.71      2338
#
#     accuracy                           0.83      9769
#    macro avg       0.78      0.85      0.80      9769
# weighted avg       0.87      0.83      0.84      9769
#
# Balanced Accuracy: 0.8459

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = bal_acc                     # replace 0 with your answer, use variable or expression from above

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8459

# %%
 # Your answer here

a4b =   0.78              # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7800

# %%
 # Your answer here

a4c = 0.85                   # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8500

# %% [markdown]
# ## **Problem Five: Analytical Questions**
#
# Select the single **best** answer to each of the following multiple choice questions on this week's material.
#
# You may wish to review Appendix One for a brief tutorial on the various classification metrics.

# %% [markdown]
# ### Part A: Tests - Precision, Recall, and F1 in Practice
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# 1. The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# 2. The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# 3. The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.
#
# 4. The bank will correctly identify most high-income customers while also sending invitations to very few low-income customers, because a high F1 score guarantees both high precision and high recall.

# %%
# Your answer here.

a5a = 0                    # Must be one of 1, 2, 3, 4

# %%
### Do not change this cell in any way

print(f'a5a = {a5a}')
# Out:
# a5a = 0

# %% [markdown]
# ### Part B: Why Use Stratified Cross-Validation?
#
# Why is **StratifiedKFold** preferred over ordinary **KFold** for this homework?
#
# 1. It guarantees every fold has exactly the same number of observations.
# 2. It keeps approximately the same class proportions in every fold.
# 3. It prevents overfitting by using more training samples.
# 4. It automatically balances the training data by duplicating minority-class examples.

# %%
# Your answer here.

a5b = 0                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5b = {a5b}')
# Out:
# a5b = 0

# %% [markdown]
# ### Part C: Understanding Precision and Recall
#
# Suppose you lower the probability threshold used to classify someone as earning more than $50K.
#
# Which change is **most likely**?
#
# 1. Precision increases while recall decreases.
# 2. Both precision and recall increase.
# 3. Recall increases while precision decreases.
# 4. Precision, recall, and F1 always remain unchanged.

# %%
# Your answer here.

a5c = 0                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5c = {a5c}')
# Out:
# a5c = 0

# %% [markdown]
# ### Part D: Why Use a Pipeline?
#
# The homework places the `OrdinalEncoder` inside a `Pipeline` instead of encoding the entire dataset before cross-validation.
#
# What is the primary reason?
#
# 1. Pipelines train the classifier faster.
# 2. Pipelines reduce the number of hyperparameters.
# 3. Pipelines prevent data leakage during cross-validation.
# 4. Pipelines automatically improve F1 score.

# %%
# Your answer here.

a5d = 0                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5d = {a5d}')
# Out:
# a5d = 0

# %% [markdown]
# ### Part E: Early Stopping
#
# `HistGradientBoostingClassifier` is configured with a large value of `max_iter` while enabling **early stopping**.
#
# Why is this a good strategy?
#
# 1. It guarantees the model reaches the maximum number of iterations.
# 2. It allows training to stop automatically once additional iterations no longer improve validation performance.
# 3. It eliminates the need for cross-validation.
# 4. It ensures the model never overfits.

# %%
# Your answer here.

a5e = 0                   # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5e = {a5e}')
# Out:
# a5e = 0

# %% [markdown]
# ### Appendix One: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ### Appendix Two: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
