# %% [markdown]
# <a href="https://colab.research.google.com/github/Jbaner/Module-3-Assignments/blob/main/Final_Project_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Final Report
#
# ### Due: 11:59pm on August 9th (with a two hour + one minute grace period) — 50 points
#
# ### No late submissions will be accepted.
#
#
# Complete all sections of this notebook to document your final decisions, results, and broader context.
#
# You will write a **technical report** following standard conventions. Useful references include:
# - [CMU guide to structure](https://www.stat.cmu.edu/~brian/701/notes/paper-structure.pdf)
# - [Data science report example](https://www.projectpro.io/article/data-science-project-report/620)
# - The Checklist in this week’s Blackboard Lesson (aligned with HOML)
#
# Your audience is **technically literate but unfamiliar with your work**—for example, your manager or other data scientists. Your report should be clear, precise, and well-organized, combining explanation, visualizations, and interpretation.
#
# This Final Report is distinct from Milestone 2:
#
# - **Milestone 2** serves as a repository of your working code and experiments
# - **This Final Report** presents a clear, structured summary of your project for a professional audience
#
# > **Important:**
# > - Do **not** assume that readers of this report are familiar with Milestone 2. Your report should stand on its own.
# > - Do not include code, code screenshots, or code cells in this notebook. All code was submitted in Milestone 2. This report should focus on explanation, results, and interpretation.
# > - **Do not add, delete, or move cells in this notebook.** Each answer must be written entirely within its assigned Markdown cell.
# > - All answers should be inserted directly under the appropriate `Answer:` prompt. Delete the sentence "Replace this sentence with your answer in this cell--do not add additional cells" and replace it with your response.
# > - You may use any appropriate Markdown formatting (paragraphs, lists, tables, inserted graphics, LaTeX, etc.).
# > - Submit this notebook as a group via your team leader’s Gradescope account.
#
#
#
#
# ## Submission Checklist
#
# - Final Report Notebook — submitted by team leader
# - **DO NOT SUBMIT Word or PDF files!**

# %% [markdown]
# ## 1. Executive Summary [4 points]
#
# Write a 300–400 word executive summary for a **non-technical audience**, such as business stakeholders in a real estate company.
#
# Your summary should explain:
# - the objective of the project
# - key insights about the data
# - the most important findings, including a plain-language description of model performance
# - a clear recommendation or takeaway
#
# Avoid technical detail and jargon. Focus on what matters and why.

# %% [markdown]
# **1.1 Answer:**
#
# > The objective of this project is to build a machine learning model that predicts a property's assessed tax value based on its physical features, geographic location, year built, and other relevant property attributes.  From a business standpoint, accurate property value predictions provide valuable insights for stakeholders such as real estate agencies, property investors, financial institutions, and tax assessment authorities. These predictions can support property valuation, investment decision-making, pricing strategies, portfolio management, and market analysis. By automating the valuation process with data-driven models, organizations can improve efficiency, reduce reliance on manual appraisals, and make more consistent and informed decisions at scale.
#
# > The primary audience is real estate collaborators or clients seeking reliable, data-driven property valuations to support pricing, investment, and market analysis decisions. For executives, the results demonstrate a practical opportunity to support more consistent pricing and investment decisions using data. From a technical perspective, the model showed stable validation performance and generalized reasonably well to unseen properties.
#
# > The analysis showed that property values are influenced by a combination of location, property size, and structural characteristics. Geographic information, including latitude, longitude, neighborhood, and ZIP code, was particularly important in predicting property values. This indicates that where a property is located can be just as important as characteristics such as square footage, bedrooms, and bathrooms. The data also contained highly skewed property-related variables, where a relatively small number of very large or expensive properties could strongly influence predictions.
#
# > The interesting finding is that location is the strongest predictor of property tax value, with latitude, longitude, neighborhood, and ZIP code outperforming features such as square footage, bedrooms, and year built. Engineered features like log transformations and interaction terms did not significantly improve performance. The HistGradientBoostingRegressor model performed best, producing lower errors and stable results across repeated tests. It also generalized well to unseen data, while simpler linear models struggled with the complex relationships in the data. Overall, combining strong geographic features with a tree-based model provides a reliable approach for predicting property tax values.
#
# > The recommended approach is to use the HistGradientBoostingRegressor model as the primary model for Zillow property-value prediction because it consistently provided the best balance of accuracy and stability.For the business, this model can provide a stronger foundation for property valuation, pricing decisions, and investment analysis. However, the model should be viewed as a decision-support tool rather than a replacement for professional valuation. Future improvements should focus on enhancing geographic and market-related information, since location was one of the strongest predictors of property value

# %% [markdown]
# ## 2. Introduction [3 points]
#
# Introduce the topic, context, and goals of your project.
#
# You may imagine that this project was completed for a **real estate company with a small in-house data science team**.
#
# Include all of the following:
#
# - Clearly introduce the topic and context of your project
# - Describe the problem you are addressing (the problem statement) and the overall motivation for solving it
# - Clearly state the objectives and goals of your analysis (as different from the motivation)

# %% [markdown]
# **2.1 Answer:**
#
# > This project focuses on predicting residential property values using the Zillow housing dataset for a real estate company with a small in-house data science team. The company wants to use its available property and geographic information to develop a more consistent, data-driven approach to estimating home values. Although the organization has a small in-house data science team, its current valuation process depends heavily on manual review and traditional appraisal rules, which can be slow, inconsistent, and difficult to scale. Accurate valuation can support important business activities such as property pricing, investment decisions, market analysis, and identifying potentially undervalued or overvalued properties.
#
# > The core problem addressed in this project is the lack of a consistent, data-driven model that can accurately predict assessed tax value across thousands of properties. Existing methods struggle to capture the complex relationships between location, home characteristics, and market conditions, leading to unpredictable variation in estimates. Without a dependable predictive model, the company risks mispricing homes, misallocating resources, and missing opportunities for strategic investment. The motivation behind this work is to provide the organization with a modern, evidence based valuation tool that improves accuracy, reduces manual effort, and increases confidence in decision making.
#
# > Project Objectives and Goals:
# The primary objective is to develop and evaluate a predictive model for residential property values using the Zillow dataset. Specifically, the analysis aims to:
#
# >> Identify the property and geographic characteristics that are most useful for predicting property values.
#
# >> Prepare and improve the dataset through appropriate data cleaning and feature engineering.
#
# >> Compare different modeling approaches, including Linear Regression, Ridge Regression, and HistGradientBoostingRegressor, to determine which provides the best predictions.
#
# >> Select and improve the strongest-performing model  through establishing baseline performance, testing preprocessing and feature-engineering ideas, selecting the most informative features, tuning model hyperparameters, and validating the final model on a held-out test set.
#
# >> Provide a clear recommendation on how the resulting model could support real estate valuation and business decision-making.
#
# > The overall goal is therefore not simply to build the most complex model, but to identify a reliable and practical valuation approach that the company's data science team can use as a foundation for future property-value prediction and analysis.

# %% [markdown]
# ## 3. Data Description [3 points]
#
# Describe the dataset used in your analysis.
#
# Include:
# - the source of the dataset
# - the number of observations (samples) and features
# - the types of variables
# - the target variable
# - missing values or other important issues in the raw data

# %% [markdown]
# **3.1 Answer:**
#
# > The dataset used in this analysis is a reduced version of the Zillow Housing Dataset, originally released as part of the Zillow Prize competition on Kaggle. It contains detailed property-level information intended to support modeling of residential tax assessments. The dataset includes 77,613 observations and 55 features representing individual homes with a wide range of physical, structural, and geographic characteristics.
#
# > The dataset includes several types of variables. Many features are numeric, such as square footage measurements, latitude and longitude, bathroom and bedroom counts, garage size, and year built. Others are categorical, including property zoning descriptions, land-use codes, heating and cooling system types, neighborhood identifiers, and pool or fireplace flags. A few variables are ordinal, such as building quality ratings. The dataset also contains several identifier variables (parcelid) that do not carry predictive value.
#
# > The target variable for this project is taxvaluedollarcnt, which represents the assessed tax value of each property. This variable is numeric, highly skewed, and spans a wide range from modest homes valued at a few thousand dollars to luxury properties exceeding $40 million. It contains no missing values and has 50,949 unique values, indicating substantial variation across properties .
#
# > A major challenge in the raw dataset is the high percentage of missing values in many features. Several columns—such as basementsqft, architecturalstyletypeid, finishedsquarefeet13, decktypeid, storytypeid, and multiple pool-related variables—contain over 95% missing values, making them unsuitable for modeling. The dataset also includes redundant or highly correlated features, such as multiple square-footage measurements and overlapping bathroom counts, which require careful handling to avoid noise and multicollinearity.
#
# > Overall, the dataset provides rich information but requires substantial cleaning, thoughtful preprocessing, and selective feature engineering to support accurate and reliable modeling.

# %% [markdown]
# ## 4. Methodology (What you did, and why) [20 points]
#
# Focus on the **process and your reasoning**, not the results.
#
# Note: Each subsection (e.g., 4.1, 4.2, etc.) must be answered in its own Markdown cell.  Each subsection is worth 5 points.

# %% [markdown]
# ### 4.1 Analytical Framework
#
# Describe the overall framework you used to develop, compare, and evaluate your models.
#
# This section should explain the structure of your model-development process: what procedures you used, how the stages fit together, and how modeling decisions were made.
#
# > Present the detailed plots, tables, and numerical evidence supporting those decisions later in Section 5.2.
#
# Include:
#
# - how the data were used for training, validation, and final testing,
# - the primary evaluation metric you selected, such as MAE or RMSE, and why it was appropriate,
# - the procedure you used to compare alternative models, preprocessing choices, and hyperparameter settings, and
# - how validation methods, such as cross-validation, validation curves, RandomizedSearch, or Optuna, were incorporated into the model-development process.

# %% [markdown]
# **4.1 Answer:**
#
# > This project followed a structured, end-to-end modeling framework designed to ensure that every model, preprocessing choice, and tuning decision was evaluated fairly and consistently. The workflow was built to support a small in-house data science team at a real estate company, emphasizing clarity, reproducibility, and reliable model comparison.
#
# > The dataset was first split into training (80%) and held-out test data (20%). All modeling decisions—including preprocessing, feature engineering, feature selection, and hyperparameter tuning were made exclusively using the training data. The held-out test set was used only once at the end of the project to provide an unbiased estimate of final model performance. This separation ensured that no information from the test set influenced model development, preventing data leakage and preserving the integrity of the evaluation.
#
# > The primary evaluation metric was Mean Absolute Error(MAE). MAE was chosen because it is easy to interpret in business terms: it measures the average dollar difference between the model's predictions and the true tax values. Unlike RMSE, which heavily penalizes large errors, MAE provides a more stable and intuitive measure for stakeholders who need predictable, dollar level accuracy. Given the skewed distribution of property values, MAE offered a clearer picture of typical model performance.
#
# > To compare models and preprocessing strategies, the analysis relied on repeated 5-fold cross-validation(5 repeats). This method trains and validates each model across 25 different train/validation splits, producing both a mean MAE and a standard deviation. The mean MAE allowed direct comparison of accuracy, while the standard deviation revealed model stability—how consistently the model performs across different subsets of the data. This approach ensured that improvements were real.
#
# > Throughout the workflow, validation methods were used systematically. Validation curves helped identify promising ranges for key hyperparameters. RandomizedSearchCV was used to efficiently explore broader hyperparameter spaces, while GridSearchCV provided fine-grained tuning once promising regions were identified. Each tuning step was evaluated using repeated cross-validation to ensure reliability.
#
# > Together, these procedures formed a rigorous, transparent modeling framework that allowed the team to confidently select the final model based on evidence rather than intuition.

# %% [markdown]
# ### 4.2 Data Cleaning and Preprocessing
#
# Describe how you cleaned and prepared the raw data for modeling.
#
# Focus on the problems you encountered, the procedures you considered, and the reasoning behind your final preprocessing choices. Detailed plots, tables, and numerical comparisons supporting these decisions should be presented later in Section 5.2.
#
# Include:
#
# * important issues in the raw data, such as missing values, outliers, inconsistencies, or unusable features,
# * how you addressed those issues,
# * the preprocessing alternatives you considered,
# * which procedures you retained for the final analysis and why, and
# * which procedures you rejected or changed and why.

# %% [markdown]
# **4.2 Answer:**
#
# > The raw Zillow dataset required substantial cleaning before any modeling could begin. It contained many of the challenges typical in real-world real estate data: extensive missing values, redundant features, inconsistent data types, and several variables that were unusable for prediction. The goal of preprocessing was to transform this messy dataset into a reliable, fully numeric feature matrix suitable for model comparison, while preserving the information most relevant to predicting tax values.
#
# > A major issue in the raw data was the extremely high percentage of missing values in many columns. Several features—such as basementsqft, architecturalstyletypeid, finishedsquarefeet13, decktypeid, storytypeid, and multiple pool-related variables had over 95% missing values. These features were removed because they provided little usable information and would introduce noise rather than improve predictions. Identifier variables like parcelid were also dropped because they uniquely identify properties but do not describe them.
#
# > For the remaining features, missing values were handled using type-appropriate imputation. Numeric variables were imputed using the median to reduce the influence of outliers. Ordinal variables, such as building quality ratings, were imputed with median values and encoded using an ordinal encoder. Categorical variables were imputed with "Unknown" and then encoded using either frequency encoding (for high-cardinality columns like ZIP code and neighborhood) or one-hot encoding (for low-cardinality features like heating and cooling types). Boolean flags were mapped to numeric values to ensure full compatibility with tree-based models.
#
# > Several preprocessing alternatives were considered. For example, one option was to one-hot encode all categorical variables, but this would have created thousands of sparse columns due to high-cardinality geographic features. Frequency encoding was chosen instead because it preserves signal while keeping the feature space manageable. Another alternative was to scale all features, but scaling was retained only for models that require it (Ridge and Linear Regression). Tree-based models were trained on unscaled data because scaling does not improve their performance.
#
# > In the final analysis, the retained preprocessing steps were those that produced a fully numeric, compact, and information-rich dataset: dropping unusable features, imputing missing values, encoding categorical variables appropriately, and ensuring consistent transformations across training and test sets. Procedures that added complexity without improving performance—such as keeping high-missing columns or applying universal one-hot encoding—were rejected to maintain model stability and interpretability.

# %% [markdown]
# ### 4.3 Feature Engineering
#
# Describe the feature transformations and new features you considered during model development.
#
# Focus on what you tried, the purpose of each change, and the reasoning behind the features you ultimately retained. Detailed evidence comparing these choices should be presented later in Section 5.2.
#
# Include:
#
# * transformations applied to existing features,
# * new features created from the available data,
# * the motivation for each transformation or new feature,
# * which features or transformations you retained and why, and
# * which features or transformations you rejected and why.

# %% [markdown]
# **4.3 Answer:**
#
# > During model development, several feature transformations and engineered features were explored to improve predictive performance and stability. The goal was to enhance signal, reduce noise, and help the models capture meaningful relationships in the Zillow dataset.
#
# > Several transformations were tested to address skewness, scale differences, and nonlinear relationships:
#
# > Log-transforming skewed numeric features such as lotsizesquarefeet and calculatedfinishedsquarefeet.
# Motivation: These variables had extreme right‑skew, which can distort model behavior. Log transforms compress large values and make relationships more linear.
# Outcome: This transformation consistently improved performance for Ridge Regression and slightly improved stability for tree‑based models. It was retained because it produced the most reliable gains across models.
#
# > Scaling numeric features using StandardScaler.
# Motivation: Linear models require features on similar scales to avoid dominance by large-magnitude variables.
# Outcome: Scaling was retained only for linear models (Ridge, Linear Regression). It was not used for tree‑based models, which do not benefit from scaling.
#
# > New Features Created
# Two engineered features were created to capture interactions between existing variables:
#
# > sqft_quality = finished square footage x building quality
# Motivation: Larger homes with higher quality ratings may have disproportionately higher tax values.
# Outcome: This feature improved Ridge slightly but worsened Linear Regression and HistGradientBoostingRegressor. It was rejected because gains were inconsistent.
# bed_bath_ratio = bedroom count ÷ (bathroom count + 1)
# Motivation: Homes with many bedrooms but few bathrooms may be valued differently.
# Outcome: This feature did not improve any model and increased variance. It was rejected.
#
# > Feature Removal
# A set of low-value or noisy features was removed:
# Removing features like propertyzoningdesc, taxdelinquencyflag, and fireplaceflag
# Motivation: These variables had high missingness or minimal predictive value.
# Outcome: Removing them slightly worsened performance for all models. Tree-based models in particular benefit from weak signals, so removal was rejected.
#
# > Final Retained Transformations
# Log-transforming skewed numeric features
# Appropriate encoding (frequency, ordinal, one‑hot)
# Type-specific imputation
# Scaling only for linear models
# These choices were retained because they consistently improved accuracy, stability, or interpretability without adding unnecessary complexity.

# %% [markdown]
# ### 4.4 Model Selection
#
# Describe how you selected your model.
#
# Include:
# - models you tried and why
# - how you evaluated generalization
# - how validation results were used to compare models and hyperparameters
# - how the test set was reserved for the final evaluation of the selected model
# - any important trade-offs you considered, such as predictive performance, computational cost, interpretability, or model complexity

# %% [markdown]
# **4.4 Answer:**
#
# > Model selection followed a structured, evidence‑driven process designed to identify the model that best balances predictive accuracy, stability, and practical usability for a real estate company. Several models were evaluated to understand how different learning approaches handle the complexity of the Zillow dataset.
#
# > A diverse set of models was tested, including Linear Regression, Ridge Regression, and HistGradientBoostingRegressor (HGB). Linear and Ridge Regression were included because they are simple, interpretable baselines that reveal how well linear relationships alone can explain property values. HGB was selected as a more flexible, nonlinear model capable of capturing interactions and complex patterns common in real estate data. These models provided a meaningful comparison between simplicity and predictive power.
#
# > Generalization was evaluated using repeated 5-fold cross-validation (5 repeats). This method trains and validates each model across 25 different data splits, producing both a mean MAE and a standard deviation. The mean MAE measured accuracy, while the standard deviation measured stability—how consistently the model performs across different subsets of the data. This approach ensured that model comparisons were not influenced by a single lucky or unlucky train/test split.
#
# > Validation results guided every modeling decision. Models were compared based on their cross-validated MAE, and preprocessing choices—such as log transformations, interaction features, and feature removal were evaluated using the same repeated-CV procedure. Hyperparameter tuning for HGB used validation curves and randomized search to identify promising parameter ranges, followed by more focused searches. Only improvements that consistently reduced MAE and maintained low variance were retained.
#
# > The held-out test set was reserved strictly for the final evaluation. No model, preprocessing step, or hyperparameter choice was influenced by test-set performance. This ensured that the final reported accuracy reflects true generalization to unseen data.
#
# > Several trade-offs were considered. Linear models offered interpretability and low computational cost but consistently underfit the data. HGB required more tuning and was less interpretable, but it delivered substantially better accuracy and stability. Given the business need for reliable, scalable predictions, the final model selected was HistGradientBoostingRegressor, which provided the strongest and most consistent performance across all evaluation criteria.

# %% [markdown]
# ## 5. Results and Evaluation (What you found, and how well it worked) [16 points]
#
# Focus on **results, evidence, and interpretation**.
#
# Note: Each subsection (e.g., 5.1, 5.2, etc.) must be answered in its own Markdown cell.

# %% [markdown]
# ### 5.1 Model Performance (8 points)
#
# Present and interpret the performance of your selected final model.
#
# Include:
#
# * the final model you selected,
# * its performance on the final test set using your primary evaluation metric,
# * a practical interpretation of what that error means in the context of the project,
# * relevant supporting metrics, such as MAE, RMSE, or $R^2$,
# * a comparison with the most important alternative models, and
# * a comparison of training, validation, and final test performance to identify possible underfitting, overfitting, or discrepancies between validation and test results.
#
# Focus on the most informative results rather than reporting every metric or model considered.

# %% [markdown]
# **5.1 Answer:**
#
# > The final model selected for this project was the HistGradientBoostingRegressor (HGB). This model consistently outperformed all alternatives during development, offering the strongest balance of accuracy, stability, and practical reliability for predicting residential property tax values.
#
# > Using repeated 5-fold cross-validation (5 repeats), the HGB model achieved a mean validation MAE of 190,881.44  with a standard deviation of 2,961.47. These results indicate not only high accuracy but also exceptional stability: the model produced nearly identical performance across 25 different validation splits, showing that it generalizes well and is not overly sensitive to variations in the training data. This stability is important for a real estate company, as it suggests the model will behave predictably when applied to new properties. Although RMSE and R² were not the primary focus, internal checks showed that HGB captured a substantial portion of the variance in tax values and avoided extreme errors more effectively than linear models.
#
# > After all modeling decisions were finalized, the model was evaluated once on the held-out test set, which had never been used during training or tuning. On this unseen data, the final HGB model achieved a test MAE of 196,754.29. This is slightly higher than the validation MAE, but still very close, an expected and healthy pattern that indicates no overfitting. The model's performance on new properties aligns closely with what we observed during cross-validation. In practical terms, a test MAE of about 197,000 means that on average, the model's predicted tax value differs from the true assessed value by roughly 197,000. Given that the dataset includes homes ranging from 1,000 to nearly $49 million, this level of error is reasonable and reflects the inherent variability of large-scale real estate assessments. The model provides stable, data-driven estimates that are appropriate for portfolio-level forecasting, anomaly detection, and decision.
#
# > Additionally HGB delivered the lowest prediction error of all models, both before and after tuning. Its final repeated-CV MAE of 190,881 was dramatically better than Ridge (230,832) and Linear Regression (232,093) as linear models showed higher variability across validation folds. The two linear models underfit the data, unable to capture the nonlinear relationships between location, home characteristics, and tax value. HGB, by contrast, consistently delivered lower errors and greater stability.
#
# > Overall, the HGB model provides accurate, stable, and business-ready predictions, making it the strongest choice for deployment within the company's valuation workflow.

# %% [markdown]
# ### 5.2 Visualizations and Summaries (6 points)
#
# Present at least two clearly labeled visualizations or quantitative summaries that provide meaningful evidence for important modeling decisions or conclusions.
#
# Include plots, tables, or outputs from automated hyperparameter search tools that help demonstrate why particular models, preprocessing choices, features, or hyperparameter settings were retained or rejected.
#
# Insert plots and graphical outputs as clear images directly into the Markdown cell. Tables and concise quantitative summaries may be created using Markdown. Do not include code or code cells. Crop screenshots so that only the relevant material is shown, and ensure that all labels and values are readable.
#
# Each element must be clearly labeled and discussed in the text. Explain what it shows, what conclusion you draw from it, and how it supports a specific modeling decision.
#
# Notes:
#
# * You are not required to include any particular type of plot, such as a validation curve.
# * If you used automated methods such as RandomizedSearch or Optuna, include summaries, comparisons, or plots that provide evidence for your model or parameter choices.
# * Focus on the most informative evidence rather than including every plot or output produced during Milestone 2.
# * The goal is to communicate and justify your decisions, not to reproduce your experimental notebook.

# %% [markdown]
# **5.2 Answer:**
#
# > Hyperparameter Search Results Plot:
# ![image.png](data:image/png;base64,...)
#
#
# > **Conclusion** The validation curve shows that extremely small learning rates underfit the data, while very large learning rates begin to overfit. The stable region between 0.05 and 0.15 produced the lowest validation MAE, indicating the best generalization performance. The selected learning_rate of 0.1389 lies within this optimal region, providing strong evidence for its use in the final tuned model.
#
# > Feature Engineering Comparison Table:
# | Feature Engineering | HGB MAE |
# | --- | --- |
# | Baseline | 192,789 |
# | Interaction Features | 193,169 |
# | Log Transform | 192,789 |
# | Feature Removal | 192,886 |
#
# > **Conclusion:** Interaction features and feature removal did not help, while log transforms were neutral for HGB but helpful for linear models.
#
# > Output from final model(Feature selection+Tuning):
# | **Category** | **Value** |
# | --- | --- |
# | **Selected Features (20)** | latitude, longitude, finishedsquarefeet12,  calculatedfinishedsquarefeet, yearbuilt, lotsizesquarefeet, bathroomcnt, buildingqualitytypeid, rawcensustractandblock, bedroomcnt, propertycountylandusecode, regionidneighborhood, regionidcity, regionidzip, propertyzoningdesc, propertylandusetypeid, censustractandblock, fullbathcnt, airconditioningtypeid_1.0, garagetotalsqft |
# | **Best learning_rate (from validation curve)** | 0.13894954943731375 |
# | **Tuned Hyperparameters** | min_samples_leaf = 5; max_leaf_nodes = 63; max_depth = 7; learning_rate = 0.13894954943731375 |
# | **Mean CV MAE (Tuned + FS)** | **190,881.44** |
# | **Std Dev CV MAE (Tuned + FS)** | **2,961.47** |
#
# >Final Test-Set Performance Summary:
# | Metric | Value |
# | --- | --- |
# | Final Test MAE | **196,754.29** |
# | Validation MAE | 190,881.44 |
# | Validation Std Dev | 2,961.47 |
#
# > **Conclusion:** Using the top 20 selected features, the HistGradientBoostingRegressor was tuned through a validation-curve sweep and a focused RandomizedSearchCV. The optimal learning rate identified from the validation curve, and the final tuned hyperparameters, the model achieved a Mean CV MAE of $190,881.44 and a standard deviation of $2,961.47, indicating both high accuracy and strong stability across repeated cross-validation folds.
#
# >**Conclusion:** The final test-set results confirm that the HistGradientBoostingRegressor is the strongest and most reliable model for predicting residential tax assessed property values in this project. Its Final Test MAE is closely aligned with its cross-validated MAE, and the low validation standard deviation of shows that the model performs consistently across many different data splits. This tight alignment between validation and test performance demonstrates that the model generalizes well to new properties and does not suffer from overfitting.

# %% [markdown]
# ### 5.3 Model Limitations (2 points)
#
# Discuss the most important limitations or weaknesses of your final model.
#
# Base your discussion on the results and analyses completed in Milestone 2. You are not required to conduct new modeling experiments for this section, although you may include an additional numerical summary or visualization if it helps clarify your conclusions.
#
# Include, as appropriate:
#
# - evidence of underfitting, overfitting, instability, or differences among - training, validation, and test performance,
# - types of observations or properties that may be especially difficult to predict,
# - plausible explanations for the model’s limitations, and
# - one or more potential changes that might improve future performance.
#
# Focus on interpreting the model’s limitations rather than merely restating its performance metrics.

# %% [markdown]
# **5.3 Answer:**
#
# > Replace this sentence with your answer in this cell--do not add additional cells.

# %% [markdown]
# ## 6. Conclusion [4 points]
#
# Summarize the main findings and implications of your analysis. This section should not simply repeat the Executive Summary. It is written for a technical audience that has read the full report and should synthesize the evidence, limitations, and practical significance of your work.
#
# Include all of the following:
#
# * clearly state your main findings and explain how they address the original project objectives,
# * highlight the business or practical implications of those findings,
# * discuss the limitations and constraints of your analysis clearly and transparently,
# * suggest potential improvements or directions for future work, and
# * conclude with a final recommendation that addresses the original business objective.

# %% [markdown]
# **6.1 Answer:**
#
# > Replace this sentence with your answer in this cell--do not add additional cells.
